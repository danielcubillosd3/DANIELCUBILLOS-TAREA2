# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
datos ={
    "Manzanas":["Camion","Bus","Perro","Gato"],"Naranjas":[0,3,7,2]

}
compras=pd.DataFrame(datos)

url="https://raw.githubusercontent.com/ManarOmar/New-York-Airbnb-2019/master/AB_NYC_2019.csv"
data=pd.read_csv(url)
data.head()
data.shape
data.info()
data["id"].is_unique
print(len(data))
print(data["host_id"].nunique())

columnas=["price","minimum_nights","number_of_reviews","reviews_per_month","calculated_host_listings_count","availability_365"]
data[columnas].describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  object
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  object
#  4   neighbourhood_group             48895 non-null  object
#  5   neighbourhood                   48895 non-null  object
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  object
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
#  12  last_review                     38843 non-null  object
#  13  reviews_per_month               38843 non-null  float64
#  14  calculated_host_listings_count  48895 non-null  int64
#  15  availability_365                48895 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 6.0+ MB
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_520/1987775601.py in <cell line: 0>()
#      14 data.info()
#      15 data["id"].is_unique
# ---> 16 print(len(data))
#      17 print(data["host_id"].nunique())
#      18
#
# TypeError: 'tuple' object is not callable

# %%
numericas=data[columnas]
numericas=numericas.fillna(numericas.mean())
sin_reseña=data["number_of_reviews"]==0
#Sin reseñas
print=("Anuncios sin reseñas",sin_reseña.sum())

# %%
data['neighbourhood'].value_counts()
data['room_type'].value_counts()
data['neighbourhood_group'].value_counts()

media=data['reviews_per_month']. mean()
print('Media de reviews_per_month:',round(media, 2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_520/268974445.py in <cell line: 0>()
#       4
#       5 media=data['reviews_per_month']. mean()
# ----> 6 print('Media de reviews_per_month:',round(media, 2))
#
# TypeError: 'tuple' object is not callable

# %%
numericas = data.select_dtypes(include=np.number)
numericas
data.boxplot(column='price', figsize=(8, 10))
plt.ylabel('Precio por noche (USD)')
plt. show()

# %%
datos_limpios = data[(data['price'] > precio_minimo) & (data['price'] <= precio_maximo)].copy()
print('Antes:', len(data), 'anuncios')
print('Después:', len (datos_limpios),'anuncios')
datos_limpios['price'].describe()
datos_limpios.boxplot(column='price', figsize=(8, 10))
plt.ylabel('Precio por noche (USD)')
plt.show()
datos_limpios['price'].hist(bins=50, figsize=(10, 5))
plt.xlabel('Precio por noche (USD)')
plt.ylabel('Anuncios')
plt.title('Distribución del precio')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_520/3618123587.py in <cell line: 0>()
# ----> 1 datos_limpios = data[(data['price'] > precio_minimo) & (data['price'] <= precio_maximo)].copy()
#       2 print('Antes:', len(data), 'anuncios')
#       3 print('Después:', len (datos_limpios),'anuncios')
#       4 datos_limpios['price'].describe()
#       5 datos_limpios.boxplot(column='price', figsize=(8, 10))
#
# NameError: name 'precio_minimo' is not defined

# %%
corte_economico = 80
corte_medio = 200
def categoria_precio(precio):
  if precio <= corte_economico:
    return 'económico'
  elif precio <= corte_medio:
    return 'medio'
  else:
    return 'premium'

# %%
datos_limpios = data[(data['price'] > precio_minimo) & (data['price'] <= precio_maximo)].copy()
corte_economico = 80
corte_medio = 200
def categoria_precio(precio):
  if precio <= corte_economico:
    return 'económico'
  elif precio <= corte_medio:
    return 'medio'
  else:
    return 'premium'
datos_limpios['categoria'] = datos_limpios['price']. apply(categoria_precio)
datos_limpios[' categoria']. value_counts ()
# Out:
#   File "/tmp/ipykernel_520/4176761250.py", line 1
#     datos_limpios = data[data['price'] > precio minimo & (data['price'] <= precio_maximo)].copy()
#                          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
datos_limpios. boxplot(column='price', by='room_type', figsize=(10, 6))
plt.xlabel('Tipo de habitación')
plt.ylabel('Precio por noche (USD)')
plt.title('Precio por tipo de habitación')
plt.suptitle('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_520/2500543337.py in <cell line: 0>()
# ----> 1 datos_limpios. boxplot(column='price', by='room_type', figsize=(10, 6))
#       2 plt.xlabel('Tipo de habitación')
#       3 plt.ylabel('Precio por noche (USD)')
#       4 plt.title('Precio por tipo de habitación')
#       5 plt.suptitle('')
#
# NameError: name 'datos_limpios' is not defined

# %%
datos_limpios.groupby('neighbourhood_group')['price'].median().sort_values().plot(kind='barh', color= "steelblue")
plt.xlabel('Precio mediano por noche (USD)')
plt.ylabel('')
plt.title('Precio mediano por distrito')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_520/3755960534.py in <cell line: 0>()
# ----> 1 datos_limpios.groupby('neighbourhood_group')['price'].median().sort_values().plot(kind='barh', color= "steelblue")
#       2 plt.xlabel('Precio mediano por noche (USD)')
#       3 plt.ylabel('')
#       4 plt.title('Precio mediano por distrito')
#       5 plt.show()
#
# NameError: name 'datos_limpios' is not defined

# %%
datos_limpios.boxplot(column='price', by='room_type', figsize=(10, 6))
plt.xlabel('Tipo de habitación')
plt.ylabel('Precio por noche (USD)').plt.title('Precio por tipo de habitación')
plt. suptitle('')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_520/3477460163.py in <cell line: 0>()
# ----> 1 datos_limpios.boxplot(column='price', by='room_type', figsize=(10, 6))
#       2 plt.xlabel('Tipo de habitación')
#       3 plt.ylabel('Precio por noche (USD)').plt.title('Precio por tipo de habitación')
#       4 plt. suptitle('')
#       5 plt.show()
#
# NameError: name 'datos_limpios' is not defined

# %%
datos_limpios.groupby('neighbourhood_group')['price'].median().sort_values().plot(kind='barh', color=' steelblue')
plt.xlabel('Precio mediano por noche (USD)')
plt.ylabel('')
plt.title('Precio mediano por distrito')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_520/3997446602.py in <cell line: 0>()
# ----> 1 datos_limpios.groupby('neighbourhood_group')['price'].median().sort_values().plot(kind='barh', color=' steelblue')
#       2 plt.xlabel('Precio mediano por noche (USD)')
#       3 plt.ylabel('')
#       4 plt.title('Precio mediano por distrito')
#       5 plt.show()
#
# NameError: name 'datos_limpios' is not defined

# %%
data.corr
# !pip install sweetviz
# !pip install pygwalker
# !pip install dtale
import dtale
import dtale.app as dtale_app
# Activar el modo Colab obligatoriamente
dtale_app.USE_COLAB = True
d = dtale.show(data)
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.3.3-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /usr/local/lib/python3.13/dist-packages (from sweetviz) (2.2.3)
# Requirement already satisfied: numpy>=1.16.0 in /usr/local/lib/python3.13/dist-packages (from sweetviz) (2.1.3)
# Requirement already satisfied: matplotlib>=3.1.3 in /usr/local/lib/python3.13/dist-packages (from sweetviz) (3.10.0)
# Requirement already satisfied: tqdm>=4.43.0 in /usr/local/lib/python3.13/dist-packages (from sweetviz) (4.67.3)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.13/dist-packages (from sweetviz) (1.16.3)
# Requirement already satisfied: jinja2>=2.11.1 in /usr/local/lib/python3.13/dist-packages (from sweetviz) (3.1.6)
# Collecting importlib_resources>=1.2.0 (from sweetviz)
#   Downloading importlib_resources-7.1.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2>=2.11.1->sweetviz) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.1.3->sweetviz) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.1.3->sweetviz) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.1.3->sweetviz) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.1.3->sweetviz) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.1.3->sweetviz) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2026.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.17.0)
# Downloading sweetviz-2.3.3-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 63.1 MB/s eta 0:00:00
# Downloading importlib_resources-7.1.0-py3-none-any.whl (37 kB)
# Installing collected packages: importlib_resources, sweetviz
# Successfully installed importlib_resources-7.1.0 sweetviz-2.3.3
# Collecting pygwalker
#   Downloading pygwalker-0.5.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.13/dist-packages (from pygwalker) (0.9.21)
# Collecting appdirs (from pygwalker)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: arrow in /usr/local/lib/python3.13/dist-packages (from pygwalker) (1.4.0)
# Collecting astor (from pygwalker)
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.13/dist-packages (from pygwalker) (6.2.6)
# Requirement already satisfied: duckdb<2.0.0,>=0.10.4 in /usr/local/lib/python3.13/dist-packages (from pygwalker) (1.3.2)
# Collecting gw-dsl-parser==0.1.49.1 (from pygwalker)
#   Downloading gw_dsl_parser-0.1.49.1-py3-none-any.whl.metadata (1.2 kB)
# Collecting ipylab<=1.0.0 (from pygwalker)
#   Downloading ipylab-1.0.0-py3-none-any.whl.metadata (6.7 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.13/dist-packages (from pygwalker) (7.34.0)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.13/dist-packages (from pygwalker) (7.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from pygwalker) (3.1.6)
# Collecting kanaries-track==0.0.5 (from pygwalker)
#   Downloading kanaries_track-0.0.5-py3-none-any.whl.metadata (913 bytes)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from pygwalker) (2.1.3)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from pygwalker) (26.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from pygwalker) (2.2.3)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from pygwalker) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.13/dist-packages (from pygwalker) (23.0.1)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.13/dist-packages (from pygwalker) (2.13.5)
# Requirement already satisfied: pytz in /usr/local/lib/python3.13/dist-packages (from pygwalker) (2025.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from pygwalker) (2.32.4)
# Collecting segment-analytics-python==2.2.3 (from pygwalker)
#   Downloading segment_analytics_python-2.2.3-py2.py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.13/dist-packages (from pygwalker) (2.0.52)
# Requirement already satisfied: sqlglot>=23.15.8 in /usr/local/lib/python3.13/dist-packages (from pygwalker) (25.20.2)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.13/dist-packages (from pygwalker) (5.7.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.13/dist-packages (from pygwalker) (4.16.0)
# Collecting wasmtime>=12.0.0 (from gw-dsl-parser==0.1.49.1->pygwalker)
#   Downloading wasmtime-48.0.0-py3-none-manylinux1_x86_64.whl.metadata (5.1 kB)
# Collecting backoff>=2.2.1 (from kanaries-track==0.0.5->pygwalker)
#   Downloading backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# Collecting dateutils>=0.6.12 (from kanaries-track==0.0.5->pygwalker)
#   Downloading dateutils-0.6.12-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting monotonic~=1.5 (from segment-analytics-python==2.2.3->pygwalker)
#   Downloading monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: python-dateutil~=2.2 in /usr/local/lib/python3.13/dist-packages (from segment-analytics-python==2.2.3->pygwalker) (2.9.0.post0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->pygwalker) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->pygwalker) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->pygwalker) (3.6.10)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.13/dist-packages (from ipywidgets->pygwalker) (3.0.17)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.13/dist-packages (from ipython->pygwalker) (80.10.2)
# Collecting jedi>=0.16 (from ipython->pygwalker)
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython->pygwalker) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython->pygwalker) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython->pygwalker) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython->pygwalker) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython->pygwalker) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.13/dist-packages (from ipython->pygwalker) (0.2.2)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython->pygwalker) (4.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->pygwalker) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->pygwalker) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->pygwalker) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.13/dist-packages (from requests->pygwalker) (2026.7.22)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.13/dist-packages (from anywidget->pygwalker) (0.15.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.13/dist-packages (from arrow->pygwalker) (2026.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from jinja2->pygwalker) (3.0.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic->pygwalker) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic->pygwalker) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic->pygwalker) (0.4.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.13/dist-packages (from sqlalchemy->pygwalker) (3.5.5)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (1.8.15)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (7.4.9)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (1.6.0)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (26.2.1)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=4.5.1->ipywidgets->pygwalker) (6.5.7)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython->pygwalker) (0.8.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.13/dist-packages (from pexpect>4.3->ipython->pygwalker) (0.7.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->pygwalker) (0.8.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil~=2.2->segment-analytics-python==2.2.3->pygwalker) (1.17.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.13/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (6.5.7)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pygwalker) (0.4)
# Requirement already satisfied: jupyter-core>=4.9.2 in /usr/local/lib/python3.13/dist-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pygwalker) (5.9.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (25.1.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (5.11.1)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (7.17.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.26.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.13/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (1.3.3)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from jupyter-core>=4.9.2->jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->pygwalker) (4.11.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.13/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (4.26.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.13/dist-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (26.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (1.5.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (2026.6.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.13/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (2.20.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (2.9.2)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (4.14.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (1.9.2)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (4.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->pygwalker) (1.3.1)
# Downloading pygwalker-0.5.0.1-py3-none-any.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 53.7 MB/s eta 0:00:00
# Downloading gw_dsl_parser-0.1.49.1-py3-none-any.whl (956 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.2/956.2 kB 40.2 MB/s eta 0:00:00
# Downloading kanaries_track-0.0.5-py3-none-any.whl (8.6 kB)
# Downloading segment_analytics_python-2.2.3-py2.py3-none-any.whl (24 kB)
# Downloading ipylab-1.0.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 7.8 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading backoff-2.2.1-py3-none-any.whl (15 kB)
# Downloading dateutils-0.6.12-py2.py3-none-any.whl (5.7 kB)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 69.2 MB/s eta 0:00:00
# Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Downloading wasmtime-48.0.0-py3-none-manylinux1_x86_64.whl (9.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 73.0 MB/s eta 0:00:00
# Installing collected packages: monotonic, appdirs, wasmtime, jedi, backoff, astor, segment-analytics-python, gw-dsl-parser, dateutils, kanaries-track, ipylab, pygwalker
# Successfully installed appdirs-1.4.4 astor-0.8.1 backoff-2.2.1 dateutils-0.6.12 gw-dsl-parser-0.1.49.1 ipylab-1.0.0 jedi-0.20.0 kanaries-track-0.0.5 monotonic-1.6 pygwalker-0.5.0.1 segment-analytics-python-2.2.3 wasmtime-48.0.0
# Collecting dtale
#   Downloading dtale-3.22.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting lz4 (from dtale)
#   Downloading lz4-4.4.5-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in /usr/local/lib/python3.13/dist-packages (from dtale) (4.13.5)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from dtale) (2026.7.22)
# Requirement already satisfied: cycler in /usr/local/lib/python3.13/dist-packages (from dtale) (0.12.1)
# Collecting dash (from dtale)
#   Downloading dash-4.4.1-py3-none-any.whl.metadata (11 kB)
# Collecting dash-bootstrap-components (from dtale)
#   Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: et_xmlfile in /usr/local/lib/python3.13/dist-packages (from dtale) (2.0.0)
# Requirement already satisfied: Flask in /usr/local/lib/python3.13/dist-packages (from dtale) (3.1.3)
# Collecting Flask-Compress (from dtale)
#   Downloading flask_compress-1.24-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: future>=0.14.0 in /usr/local/lib/python3.13/dist-packages (from dtale) (1.0.0)
# Requirement already satisfied: itsdangerous in /usr/local/lib/python3.13/dist-packages (from dtale) (2.2.0)
# Collecting kaleido (from dtale)
#   Downloading kaleido-1.4.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.13/dist-packages (from dtale) (3.10.0)
# Requirement already satisfied: missingno in /usr/local/lib/python3.13/dist-packages (from dtale) (0.5.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.13/dist-packages (from dtale) (3.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.13/dist-packages (from dtale) (2.1.3)
# Requirement already satisfied: openpyxl!=3.2.0b1 in /usr/local/lib/python3.13/dist-packages (from dtale) (3.1.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from dtale) (26.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.13/dist-packages (from dtale) (2.2.3)
# Collecting pkginfo (from dtale)
#   Downloading pkginfo-1.13-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: plotly in /usr/local/lib/python3.13/dist-packages (from dtale) (5.24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.13/dist-packages (from dtale) (2.32.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.13/dist-packages (from dtale) (1.6.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.13/dist-packages (from dtale) (1.16.3)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.13/dist-packages (from dtale) (0.13.2)
# Collecting squarify (from dtale)
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.13/dist-packages (from dtale) (0.15.0)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in /usr/local/lib/python3.13/dist-packages (from dtale) (1.17.0)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.13/dist-packages (from dtale) (3.1.8)
# Requirement already satisfied: xarray in /usr/local/lib/python3.13/dist-packages (from dtale) (2025.12.0)
# Requirement already satisfied: xlrd in /usr/local/lib/python3.13/dist-packages (from dtale) (2.0.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4!=4.13.0b2->dtale) (4.16.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.13/dist-packages (from dash->dtale) (9.0.1)
# Collecting retrying (from dash->dtale)
#   Downloading retrying-1.4.2-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.13/dist-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.13/dist-packages (from dash->dtale) (80.10.2)
# Collecting janus>=1.0.0 (from dash->dtale)
#   Downloading janus-2.0.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pydantic>=2.10 in /usr/local/lib/python3.13/dist-packages (from dash->dtale) (2.13.5)
# Collecting comm (from dash->dtale)
#   Downloading comm-0.2.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.13/dist-packages (from Flask->dtale) (1.9.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.13/dist-packages (from Flask->dtale) (8.5.0)
# Requirement already satisfied: jinja2>=3.1.2 in /usr/local/lib/python3.13/dist-packages (from Flask->dtale) (3.1.6)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.13/dist-packages (from Flask->dtale) (3.0.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.13/dist-packages (from plotly->dtale) (9.1.4)
# Requirement already satisfied: brotli in /usr/local/lib/python3.13/dist-packages (from Flask-Compress->dtale) (1.2.0)
# Collecting backports.zstd (from Flask-Compress->dtale)
#   Downloading backports_zstd-1.7.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.8 kB)
# Collecting choreographer>=1.3.0 (from kaleido->dtale)
#   Downloading choreographer-1.3.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting logistro>=1.0.8 (from kaleido->dtale)
#   Downloading logistro-2.0.1-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: orjson>=3.10.15 in /usr/local/lib/python3.13/dist-packages (from kaleido->dtale) (3.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->dtale) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib->dtale) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->dtale) (1.5.1)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib->dtale) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib->dtale) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas->dtale) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas->dtale) (2026.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.13/dist-packages (from requests->dtale) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.13/dist-packages (from requests->dtale) (3.19)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.13/dist-packages (from requests->dtale) (2.5.0)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->dtale) (1.6.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from scikit-learn->dtale) (3.6.0)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.13/dist-packages (from statsmodels->dtale) (1.0.3)
# Requirement already satisfied: formulaic>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from statsmodels->dtale) (1.2.2)
# Requirement already satisfied: platformdirs>=4.3.6 in /usr/local/lib/python3.13/dist-packages (from choreographer>=1.3.0->kaleido->dtale) (4.11.7)
# Requirement already satisfied: simplejson>=3.19.3 in /usr/local/lib/python3.13/dist-packages (from choreographer>=1.3.0->kaleido->dtale) (4.1.2)
# Requirement already satisfied: interface-meta>=1.2.0 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->dtale) (2.0.1)
# Requirement already satisfied: narwhals>=1.17 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->dtale) (2.25.0)
# Requirement already satisfied: wrapt>=1.17.0rc1 in /usr/local/lib/python3.13/dist-packages (from formulaic>=1.1.0->statsmodels->dtale) (2.4.0)
# Requirement already satisfied: cloudpickle>=3.0 in /usr/local/lib/python3.13/dist-packages (from joblib>=1.2.0->scikit-learn->dtale) (3.1.2)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.10->dash->dtale) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.10->dash->dtale) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.10->dash->dtale) (0.4.4)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.13/dist-packages (from importlib-metadata->dash->dtale) (4.1.0)
# Downloading dtale-3.22.0-py2.py3-none-any.whl (17.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 47.8 MB/s eta 0:00:00
# Downloading dash-4.4.1-py3-none-any.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 85.8 MB/s eta 0:00:00
# Downloading dash_bootstrap_components-2.0.4-py3-none-any.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.0/204.0 kB 16.8 MB/s eta 0:00:00
# Downloading flask_compress-1.24-py3-none-any.whl (11 kB)
# Downloading kaleido-1.4.0-py3-none-any.whl (56 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.1/56.1 kB 4.4 MB/s eta 0:00:00
# Downloading lz4-4.4.5-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 34.7 MB/s eta 0:00:00
# Downloading pkginfo-1.13-py3-none-any.whl (32 kB)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.9/45.9 kB 3.1 MB/s eta 0:00:00
# Downloading choreographer-1.3.0-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.6/52.6 kB 3.8 MB/s eta 0:00:00
# Downloading janus-2.0.0-py3-none-any.whl (12 kB)
# Downloading logistro-2.0.1-py3-none-any.whl (8.6 kB)
# Downloading backports_zstd-1.7.0-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (492 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 492.7/492.7 kB 30.9 MB/s eta 0:00:00
# Downloading comm-0.2.3-py3-none-any.whl (7.3 kB)
# Downloading retrying-1.4.2-py3-none-any.whl (10 kB)
# Installing collected packages: strsimpy, squarify, retrying, pkginfo, lz4, logistro, janus, comm, backports.zstd, choreographer, kaleido, Flask-Compress, dash, dash-bootstrap-components, dtale
# Successfully installed Flask-Compress-1.24 backports.zstd-1.7.0 choreographer-1.3.0 comm-0.2.3 dash-4.4.1 dash-bootstrap-components-2.0.4 dtale-3.22.0 janus-2.0.0 kaleido-1.4.0 logistro-2.0.1 lz4-4.4.5 pkginfo-1.13 retrying-1.4.2 squarify-0.4.4 strsimpy-0.2.1
# /usr/local/lib/python3.13/dist-packages/kaleido/_sync_server.py:11: UserWarning:
#
#
#
# Warning: You have Plotly version 5.24.1, which is not compatible with this version of Kaleido (1.4.0).
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
#
# You can however, use the Kaleido API directly which will work with your plotly version. `kaleido.write_fig(...)`, for example. Please see the kaleido documentation.
